# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
# tis line allow you to see plots inside jupyter notebook
# %matplotlib inline

# %%
#without the line above you have to always call .show()

# %%
import numpy as np

# %%
x=np.linspace(0,5,11)
y= x**2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
# first way to create plot FUNCTIONAL

# %%
plt.plot(x,y)
# use plt.show() in case that you havent enable inline

# %%
plt.plot(x,y,'r-')

# %%
plt.plot(x,y)
plt.xlabel("X label")
plt.ylabel("Y label")
plt.title("Title")
# Out:
# Text(0.5, 1.0, 'Title')

# %%
# multiple plots in same canves

# %%
#(row,column,plot number)
plt.subplot(1,2,1)
plt.plot(x,y,'r')

plt.subplot(1,2,2)
plt.plot(y,x,'y')

# %%
# second way to create plot ==>> OO(OBJECT ORIENTED)

# %%
#imaginary blank canves
fig=plt.figure()
# انداره رو مشخص میکنه
axes=fig.add_axes([0.5,0.1,0.5,0.9])

# %%
fig=plt.figure()
axes=fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(x,y)
axes.set_ylabel("Y label")
axes.set_xlabel("X label")
axes.set_title("Title")
# Out:
# Text(0.5, 1.0, 'Title')

# %%
fig =plt.figure()
axes1=fig.add_axes([0.1,0.1,0.8,0.8])
#("عرض","جابه جایی","گوشه سمت چپ","hight")
axes2=fig.add_axes([0.2,0.5,0.4,0.3])

axes1.plot(x,y)
axes2.plot(y,x)
axes2.set_title("Smaller plot")
axes1.set_title("Larger plot")
# Out:
# Text(0.5, 1.0, 'Larger plot')

# %%
#subplot with OOP

# %%
fig,axes=plt.subplots(nrows=1,ncols=2)
#plt.tight_layout this line handels the overlap between subplots
for current_ax in axes:
    current_ax.plot(x,y)
#axes[0].plot(x,y)
#axes[1].plot(y,x)

# %%
axes
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %% [markdown]
# ### fiqure size and dpi

# %%
# it takes size in inch(width and hight)
# dpi shows pixels per inch
fig=plt.figure(figsize=(8,2),dpi=100)
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
fig,axes = plt.subplots(nrows=2,ncols=1,figsize=(8,2))
axes[0].plot(x,y)
axes[1].plot(y,x)
plt.tight_layout()

# %%
# save a figure

# %%
fig

# %%
fig.savefig('my_picture.png')

# %%
# if you want more detail exceed the dpi
fig.savefig('my_picture.jpg',dpi=200)

# %% [markdown]
# ## legend

# %%
fig= plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,x**2,label="X Squared")
ax.plot(x,x**3,label="X Cubed")
# loc stands for location of the legend ==>> it will be usefull in some cases that the legend overlaped with diagram
# loc=0 equals to automatically find best location
ax.legend()
#ax.legend(loc=2)
#ax.legend(loc=(0.1,0.1)) the exact location

# %% [markdown]
# ## setting colors and customize lines

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
## third parameter is color
## color ='blue'
## color='#FGA123'
## '-r'
## change tranparency by costomizing alpha
## instead of linewidth you can type lw and it will still work
ax.plot(x,y,"-r",linewidth=3,alpha=0.1)

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
## instead of linewidth you can type lw and it will still work
## line style defines the style of line such as dash or dotted
## other options '--' 'steps' '-.' ':'
## instead of line style use ls it will work fine
ax.plot(x,y,"-r",lw=3,linestyle='-.')
# Out:
# C:\Users\top\AppData\Local\Temp\ipykernel_4356\215861076.py:7: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-r" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(x,y,"-r",lw=3,linestyle='-.')

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
## marker will specify the exact place of each point ==> for example for array x you can see the exact point of data
## marker='+' or '*' or '1(any other number)'
ax.plot(x,y,"-r",lw=0.5,marker='o',markersize=10)

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])

ax.plot(x,y,"-r",lw=0.5,marker='o',markersize=10,
       markerfacecolor='yellow',markeredgewidth=3,markeredgecolor='green')

# %% [markdown]
# ## control over axis appearance

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])

ax.plot(x,y,"-r",lw=2,ls='--')
## use this when you want to show a boundry of an plot
ax.set_xlim([0,1])
## y limitation over the plot
ax.set_ylim([0,2])
# Out:
# C:\Users\top\AppData\Local\Temp\ipykernel_4356\3361116883.py:4: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-r" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(x,y,"-r",lw=2,ls='--')
# (0.0, 2.0)

# %% [markdown]
# ## special plot types

# %%
plt.scatter(x,y)

# %%
plt.hist(x,y)
# Out:
# (array([1., 1., 3., 3., 3., 0., 0., 0., 0., 0.]),
#  array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#         20.25, 25.  ]),
#  <BarContainer object of 10 artists>)
