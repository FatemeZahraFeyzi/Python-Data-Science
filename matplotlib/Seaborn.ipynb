# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
tips=sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## distplot = distribution of the univariant(one variable) set of observation

# %%
sns.distplot(tips['total_bill'])
# Out:
# C:\Users\top\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
## it will remove the kde(kernel density extimation) diagram
sns.distplot(tips['total_bill'],kde=False)
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
#bins= it shows the number of parts that x axis will divided to
sns.distplot(tips['total_bill'],kde=False,bins=30)
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %% [markdown]
# ## jopint plot= it allows you to combine two different distplot(two variables)

# %%
## use x and y to define wich variables(columns,features) you are going to compare
sns.jointplot(x='total_bill',y='tip',data=tips)

# %%
# kind parameter allows you to set the type of inside diagram
sns.jointplot(x='total_bill',y='tip',data=tips,kind='hex')

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='reg')

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='kde')

# %%
sns.jointplot(x='total_bill',y='tip',data=tips)

# %% [markdown]
# ## pairplot will show pairwise relationship across an entire dataframe or at least for numereical columns
#
# it will joint plot for every single possible combination of numerical columns in datafarame

# %%
sns.pairplot(tips)

# %%
#hue paremeter is for passing the name of categorical columns and seperate data base on it
sns.pairplot(tips,hue='sex')

# %%
#palette alows you to color your plot
sns.pairplot(tips,hue='sex',palette='coolwarm')

# %%
# despite of histogram this plot is horizental ;)
sns.rugplot(tips['total_bill'])
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
# kde (kernel density estimation)
sns.kdeplot(tips['total_bill'])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# ## categorical plots

# %%
import seaborn as sns
# %matplotlib inline
tips= sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# it shows the average or mean a non-categoricalk column base of categorical column
sns.barplot(x='sex',y='total_bill',data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
import numpy as np

# %%
## by deafault the estimator is mean but we can change it
## this exacly doing group by mechanism
sns.barplot(x='sex',y='total_bill',data=tips,estimator=np.std)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
#this is the barplot but the estimator is the number of each category
sns.countplot(x='sex',data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %% [markdown]
# ## boxplot is used to show distribution on categorical variable
# box or whisker plot

# %%
# for each category of categorical variable it shows the box plot
sns.boxenplot(x='day',y='total_bill',data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
# add another categorical variable
sns.boxenplot(x='day',y='total_bill',data=tips,hue='smoker')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.boxenplot(x='day',y='total_bill',data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
#it will show the distribution of data across some sort of category
# this plot unlike the box plot allows us to actually plot all the components that 
## correspond to actual data points and it is essentially showing the kernel density eatimation of underlying distribution
sns.violinplot(x='day',y='total_bill',data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day',y='total_bill',data=tips,hue='sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day',y='total_bill',data=tips,hue='sex',split=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ## stript plot

# %%
#it will draw a scatter plot when one variable is categorical
sns.stripplot(x='day',y='total_bill',data=tips)
# this is an issue with scatter plot that you dont khow how many points are stack on top of each other
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
# to fix that above issue
# jitter will add a little bit of random noise to seperate some of stacked points
sns.stripplot(x='day',y='total_bill',data=tips,jitter=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x='day',y='total_bill',data=tips,jitter=True,hue='sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x='day',y='total_bill',data=tips,jitter=True,hue='sex',split=True)
# Out:
# C:\Users\top\anaconda3\lib\site-packages\seaborn\categorical.py:2805: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ## swarm plot

# %%
#its simmilar to striptplot except that points are adjusted and dont overlap
sns.swarmplot(x='day',y='total_bill',data=tips)
# not to use this plot for a large data set
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day',y='total_bill',data=tips)
sns.swarmplot(x='day',y='total_bill',data=tips,color='black')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
# there is a kind argument is going to describe what is going on with factor plot itself
# it will define kind of chart
sns.factorplot(x='day',y='total_bill',data=tips,kind='bar')
# Out:
# C:\Users\top\anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# ## matrix plots

# %%
import seaborn as sns
# %matplotlib inline

# %%
tips=sns.load_dataset('tips')

# %%
flights=sns.load_dataset('flights')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %% [markdown]
# ### in order to heatmap do well the data must be in matrix for(both columns and rows must be variables)

# %%
# first way to get data in matrix form
tc=tips.corr()

# %%
sns.heatmap(tc)
# Out:
# <AxesSubplot:>

# %%
#annot=true will show the actual value of each cell
#cmap will define a color map
sns.heatmap(tc,annot=True,cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %% [markdown]
# # we can create a matrix form by pivote_table

# %%
fp=flights.pivot_table(index='month',columns='year',values='passengers')

# %%
sns.heatmap(fp)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
# magma create colors from dark to light
sns.heatmap(fp,cmap='magma')
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.heatmap(fp,cmap='magma',linecolor='white',linewidth=2)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.heatmap(fp,cmap='coolwarm',linecolor='white',linewidth=2)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.heatmap(fp)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %% [markdown]
# ## clustermap = it uses the hierarichal clustering to produce a clustered version of this heatmap

# %%
sns.clustermap(fp)

# %%
sns.clustermap(fp,cmap='coolwarm')

# %%
# standard scale will normalize the scale of value
sns.clustermap(fp,cmap='coolwarm',standard_scale=1)

# %% [markdown]
# # Grids

# %%
import seaborn as sns
# %matplotlib inline
iris= sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
sns.pairplot(data=iris)

# %%
# pair plot is a simplified version of pair grid
import matplotlib.pyplot as plt
g= sns.PairGrid(iris)
## with map we can change the type of plot in cells
g.map(plt.scatter)

# %%
# more control in diag, upper side and lower side
g=sns.PairGrid(iris)
g.map_diag(sns.distplot)
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot)
# Out:
# C:\Users\top\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\top\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# facetgrid

# %%
# rows and columns define what variable you want to separate by for your fassett grid
g= sns.FacetGrid(data=tips,col='time',row='smoker')
# when you maping you will add one more variable wich is going to actuallu map based of it
g.map(sns.histplot,'total_bill')

# %%
# rows and columns define what variable you want to separate by for your fassett grid
g= sns.FacetGrid(data=tips,col='time',row='smoker')
# scatter plot needs to arguments so we have to pass both
g.map(sns.scatterplot,'total_bill','tip')

# %% [markdown]
# # regression plots

# %%
# lm plots : allows you to display linear models

# %%
import seaborn as sns
# %matplotlib inline
tips= sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lmplot(x='total_bill',y='tip',data=tips)

# %%
#you can add hue if you want some separation based on categorical feature
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex')

# %%
# you can also add markers
# lmplot is the call of matplotlit in seaborn and pass costomization to it
# if you want to affect matplotlib directly from seaborn use scatter_plot and add parameter 
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',markers=['o','v'],
           scatter_kws={'s':100})

# %%
# you can actually use grid instead of separating by hue
sns.lmplot(x='total_bill',y='tip',data=tips,col='sex')

# %%
# you can actually use grid instead of separating by hue
sns.lmplot(x='total_bill',y='tip',data=tips,col='sex',row='time')

# %%
# if you still need more variables you can add hue
sns.lmplot(x='total_bill',y='tip',data=tips,col='day',row='time',hue='sex')

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,col='day',hue='sex')

# %%
#aspect ==> this is the ratio between the hight and width of each of these separate grids
sns.lmplot(x='total_bill',y='tip',data=tips,col='day',hue='sex',
          aspect=0.6,size=8)
# Out:
# C:\Users\top\anaconda3\lib\site-packages\seaborn\regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
